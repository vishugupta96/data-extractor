# %%
import json
import pandas as pd
from selenium import webdriver      
import time  
   
from selenium.webdriver.common.keys import Keys  
youtube = {'followers':'','description':'','lifetime_views':''}
browser = webdriver.Chrome(executable_path = "chromedriver.exe")  
browser.get('https://www.youtube.com/channel/UCfLdIEPs1tYj4ieEdJnyNyw') 
time.sleep(2) 
followers = browser.find_elements_by_xpath("//yt-formatted-string[starts-with(@id,'subscriber-count')]")
# print(followers[0].text)
youtube['followers'] = followers[0].text
#PATH = input("Enter the Webdriver path: ")
browser.maximize_window()
time.sleep(2)
description = browser.find_elements_by_xpath('//*[@id="tabsContent"]/tp-yt-paper-tab[7]/div')
print(description[0].text)
time.sleep(2)
description[0].click()
time.sleep(2)

youtube['description'] = description[0].text
description = browser.find_element_by_xpath("//yt-formatted-string[starts-with(@id,'description')]")
# print(description.text)
lifetime_views = browser.find_element_by_xpath("//*[@id='right-column']/yt-formatted-string[3]")
# print(lifetime_views.text)
youtube['lifetime_views'] = lifetime_views.text
vids_tab = browser.find_element_by_xpath('//*[@id="tabsContent"]/tp-yt-paper-tab[2]/div')
# print(vids_tab.text)
# Out:
# ABOUT

# %%
time.sleep(2)
vids_tab.click()
time.sleep(2)
browser.execute_script("window.scrollTo(2, 1080)")
time.sleep(2)

# for i in comments:
#     print('sdafgadfsgfdsf')
#     print(i.text)
#     print('suck')

# %%
browser.execute_script("window.scrollTo(2, 1080)")
videos = browser.find_element_by_xpath('/html/body/ytd-app/div/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-grid-renderer/div[1]')
a = []


for i in range(1,25):
    c = {}
    t = videos.find_element_by_xpath('//*[@id="items"]/ytd-grid-video-renderer['+ str(i)+']')
    print(t.text.split('\n'))
    list_ = t.text.split('\n')
    for i in range(len(list_)):
        if i == 0:
            c['duration'] = list_[i]
        if i == 1:
            c['name'] = list_[i]
        if i == 2:
            c['views'] = list_[i]
        if i == 3:
            c['time'] = list_[i]
    a.append(c)
    
    
    
time.sleep(2)
browser.find_element_by_xpath('/html/body/ytd-app/div/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-grid-renderer/div[1]/ytd-grid-video-renderer[1]/div[1]/ytd-thumbnail/a').click()
time.sleep(2)
# Out:
# ['1:00:44', 'Breaking Modern Loneliness, May 2021', '467K views', '7 months ago']
# ['3:16', 'Lauv - 2021 [Official Audio]', '1.5M views', '1 year ago']
# ['2:26', 'Lauv & Conan Gray - Fake [Acoustic]', '967K views', '1 year ago']
# ['1:28', 'Lauv & Conan Gray - Fake [Behind The Scenes of the Music Video]', '140K views', '1 year ago']
# ['47:44', 'Breaking Modern Loneliness: Conversations on Mental Health (Finding Mental Health Online)', '19K views', '1 year ago']
# ['2:43', 'Lauv & Conan Gray - Fake [Official Music Video]', '13M views', '1 year ago']
# ['40:29', 'Breaking Modern Loneliness: Conversations on Mental Health (Finding Mental Health in Community)', '32K views', 'Streamed 1 year ago']
# ['1:09:57', 'Breaking Modern Loneliness: Conversations on Mental Health (Finding Mental Health in Isolation)', '214K views', 'Streamed 1 year ago']
# ['1:17', 'Breaking Modern Loneliness: World Mental Health Day', '70K views', '1 year ago']
# ['2:33', 'Lauv - Love Somebody [Acoustic for Digital FADER FORT]', '862K views', '1 year ago']
# ['2:24', 'Lauv - Love Somebody [Official Video]', '6.7M views', '1 year ago']
# ['2:22', 'Lauv - Dishes (Acoustic) [Official Audio]', '294K views', '1 year ago']
# ['0:58', 'Lauv - YouTube Berlin Event [Recap]', '43K views', '1 year ago']
# ['2:39', 'Lauv - Dishes [Official Video]', '2.4M views', '1 year ago']
# ['2:23', 'Lauv - Love Somebody [Official Audio]', '1.9M views', '1 year ago']
# ['1:59', 'Lauv - Miss Me (Demo) [Official Audio]', '934K views', '1 year ago']
# ['3:27', "Lauv - Mine (You Can't Find Love in Mollywood) [Official Audio]", '1.8M views', '1 year ago']
# ['43:02', 'Breaking Modern Loneliness: mxmtoon [Episode 1]', '73K views', '1 year ago']
# ['28:56', 'Breaking Modern Loneliness: Jeremy Zucker [Episode 3]', '96K views', '1 year ago']
# ['34:41', 'Breaking Modern Loneliness: Dr. Vivek Murthy [Episode 2]', '19K views', '1 year ago']
# ['4:09', 'Lauv - El Tejano (feat. Sofía Reyes) [Official Video]', '4.6M views', '1 year ago', 'CC']
# ['3:05', 'Lauv - Love Like That [Official Audio]', '2.6M views', '1 year ago']
# ['58:39', 'Breaking Modern Loneliness: A Conversation on Mental Health', '266K views', 'Streamed 1 year ago', 'Fundraiser']
# ['4:07', 'Lauv - Modern Loneliness (MTV Live Performance)', '521K views', '1 year ago']
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6064/2128170827.py in <module>
#      23
#      24 time.sleep(2)
# ---> 25 browser.find_element_by_xpath('/html/body/ytd-app/div/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-grid-renderer/div[1]/ytd-grid-video-renderer[1]/div[1]/ytd-thumbnail/a').click()
#      26 time.sleep(2)
#
# d:\Users\kavis\miniconda3\envs\tflow2\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# d:\Users\kavis\miniconda3\envs\tflow2\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
#
# d:\Users\kavis\miniconda3\envs\tflow2\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# d:\Users\kavis\miniconda3\envs\tflow2\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <a id="thumbnail" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" aria-hidden="true" tabindex="-1" rel="null" href="/watch?v=OHioqT9d-kY">...</a> is not clickable at point (455, 58). Other element would receive the click: <tp-yt-paper-tab class="style-scope ytd-c4-tabbed-header-renderer" role="tab" aria-disabled="false" aria-selected="false" tabindex="0">...</tp-yt-paper-tab>
#   (Session info: chrome=97.0.4692.71)

# %%
browser.find_element_by_xpath('/html/body/ytd-app/div/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-grid-renderer/div[1]/ytd-grid-video-renderer[1]/div[1]/ytd-thumbnail/a').click()

# %%
youtube['videos']  = a

# %%
time.sleep(2)
for i in range(15):
    browser.execute_script("window.scrollTo(0, 1080)")
    time.sleep(1)
asd = browser.find_element_by_xpath('/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/ytd-comments/ytd-item-section-renderer/div[1]/ytd-comments-header-renderer/div[1]/h2')
# asd.text.split(' ')

# %%
 youtube['comments_count'] = asd.text.split(' ')[0]

# %%
 youtube['comments_count']
# Out:
# '170'

# %%
a = []

comments = browser.find_element_by_xpath('/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/ytd-comments/ytd-item-section-renderer/div[3]')
time.sleep(2)
browser.execute_script("window.scrollTo(2, 1080)")
time.sleep(2)
for i in range(2,20):
    c = {}
    t = comments.find_element_by_xpath('//*[@id="contents"]/ytd-comment-thread-renderer['+ str(i)+']')
    print(t.text.split('\n'))
    list_ = t.text.split('\n')
    for i in range(len(list_)):
        if i == 0:
            c['name'] = list_[i]
        if i == 1:
            c['time'] = list_[i]
        if i == 2:
            c['comments'] = list_[i]
        if i == 3:
            c['likes'] = list_[i]
    a.append(c)
# Out:
# ['aestaetic ʕ•ᴥ•ʔ', '7 months ago', 'Lauv and Alec! What a powerful duo this would be! :D', '162', 'REPLY', 'View 7 replies']
# ['TwoFeet', '7 months ago', 'Thanks for having me <3 sorry for not saying much in the beginning it can be hard to talk about. Love you guys.', '260', 'REPLY', 'View 9 replies']
# ['LyricsThisWeekend', '7 months ago', 'Alec and Lauv, we love you guys both!!! ', 'My special message is to Alec tho,', "you're so amazing, you have such an angelic voice 💫💫💫💖💖💖", '30', 'REPLY']
# ['arimar', '7 months ago', 'I love the music of Alec benjamín and that of Lauv Haci this will be an extraordinary bomb of beautiful voices💥💥💥💜💜💙💙💯', '95', 'REPLY', 'View reply']
# ['Mars Loli', '7 months ago', 'Thanks for this Lauv, I definitely needed this, seeing celebrities talking about their issues and comments on mental health is amazing <3', '5', 'REPLY']
# ['Nayana', '7 months ago', 'Holy fuck what I didn’t expect this duo but I honestly love it they are both my fav artists ❤️', '39', 'REPLY']
# ['Josh Yuknowwho', '7 months ago', 'Alec is the best person to share your thoughts with', '8', 'REPLY']
# ['Nicol3', '7 months ago', 'Hope to break this Modern Loneliness within soon 🤞So much love for Lauv ❤️', '5', 'REPLY']
# ['Lob zan', '7 months ago (edited)', 'Okay so i just finished this whole conversation i mean such a good inititaive by Lauv and blue foundation .I found everyone in the video so sweet but Two Feet stood out for me as those who watched from the very beginning to the end would know at first he seem lil uncomfortable sharing but as he listens to others sharing their experiences he also shared his darkest moments in life and at the end of the conversation he seems so comfortable and happy to share those with them and to all the people out there and the way he said he love his dog i mean wow...i just loved how he became comfortable at the end', 'Read more', '11', 'REPLY']
# ['Ayushi Maldeniya', '7 months ago', 'I love this song so much! It helps me a lot during bad times 🤍', '17', 'REPLY', 'View 3 replies']
# ['Sneakermikaa', '7 months ago', 'I kind of liked the way that they made me think about all of these questions and try to answer them myself..It was like I had a chat with all of them myself...that was awesome.', 'Huge thank you♡', '4', 'REPLY']
# ['Jieun Jeannie Oh', '7 months ago', 'It was really good to hear public figures share their personal experience, ', 'And now i’m thinking all people are same, and we all try to overcome their mood issues which is great 💪🏻', 'i appreciate to everyone who opened up their stories although darkest memories🙏🏻🙏🏻 ', 'it’s important to share your loneliness with people who around you and that got me out of depression :)', '6', 'REPLY']
# ['Call me Wolfie', '7 months ago', 'you guys are just amazing.', '6', 'REPLY']
# ['Desang', '7 months ago', "These people are so inspiring and yet.. We all facing different struggle everyday but here's a reminder that we are not alone. 💖 Thank you so much Lauv 💞", '3', 'REPLY']
# ['Drake Vermillion', '3 months ago', "I actually watched this video till the end and I learned a lot from these lovely artists. Mental health is really important especially on this era, lot of people tend to hide and ignore their feelings and ain't open up their  problems to friends and family.", 'REPLY']
# ['Tri Febiani', '7 months ago', 'always love ur music so bad💙', '6', 'REPLY', 'View reply']
# ['heidewia', '7 months ago', 'conversations about  mental health on my birthday, thank you Blue Boy Foundation 🤍', '8', 'REPLY']
# ['Leslie Hipolito', '7 months ago', 'Thank you for this! ❤️😥', '2', 'REPLY']

# %%
youtube['comments']  = a

# %%
youtube
# Out:
# {'followers': '4.17M subscribers',
#  'description': 'ABOUT',
#  'lifetime_views': '1,689,874,864 views',
#  'vids': [],
#  'videos': [{'duration': '1:00:44',
#    'name': 'Breaking Modern Loneliness, May 2021',
#    'views': '467K views',
#    'time': '7 months ago'},
#   {'duration': '3:16',
#    'name': 'Lauv - 2021 [Official Audio]',
#    'views': '1.5M views',
#    'time': '1 year ago'},
#   {'duration': '2:26',
#    'name': 'Lauv & Conan Gray - Fake [Acoustic]',
#    'views': '967K views',
#    'time': '1 year ago'},
#   {'duration': '1:28',
#    'name': 'Lauv & Conan Gray - Fake [Behind The Scenes of the Music Video]',
#    'views': '140K views',
#    'time': '1 year ago'},
#   {'duration': '47:44',
#    'name': 'Breaking Modern Loneliness: Conversations on Mental Health (Finding Mental Health Online)',
#    'views': '19K views',
#    'time': '1 year ago'},
#   {'duration': '2:43',
#    'name': 'Lauv & Conan Gray - Fake [Official Music Video]',
#    'views': '13M views',
#    'time': '1 year ago'},
#   {'duration': '40:29',
#    'name': 'Breaking Modern Loneliness: Conversations on Mental Health (Finding Mental Health in Community)',
#    'views': '32K views',
#    'time': 'Streamed 1 year ago'},
#   {'duration': '1:09:57',
#    'name': 'Breaking Modern Loneliness: Conversations on Mental Health (Finding Mental Health in Isolation)',
#    'views': '214K views',
#    'time': 'Streamed 1 year ago'},
#   {'duration': '1:17',
#    'name': 'Breaking Modern Loneliness: World Mental Health Day',
#    'views': '70K views',
#    'time': '1 year ago'},
#   {'duration': '2:33',
#    'name': 'Lauv - Love Somebody [Acoustic for Digital FADER FORT]',
#    'views': '862K views',
#    'time': '1 year ago'},
#   {'duration': '2:24',
#    'name': 'Lauv - Love Somebody [Official Video]',
#    'views': '6.7M views',
#    'time': '1 year ago'},
#   {'duration': '2:22',
#    'name': 'Lauv - Dishes (Acoustic) [Official Audio]',
#    'views': '294K views',
#    'time': '1 year ago'},
#   {'duration': '0:58',
#    'name': 'Lauv - YouTube Berlin Event [Recap]',
#    'views': '43K views',
#    'time': '1 year ago'},
#   {'duration': '2:39',
#    'name': 'Lauv - Dishes [Official Video]',
#    'views': '2.4M views',
#    'time': '1 year ago'},
#   {'duration': '2:23',
#    'name': 'Lauv - Love Somebody [Official Audio]',
#    'views': '1.9M views',
#    'time': '1 year ago'},
#   {'duration': '1:59',
#    'name': 'Lauv - Miss Me (Demo) [Official Audio]',
#    'views': '934K views',
#    'time': '1 year ago'},
#   {'duration': '3:27',
#    'name': "Lauv - Mine (You Can't Find Love in Mollywood) [Official Audio]",
#    'views': '1.8M views',
#    'time': '1 year ago'},
#   {'duration': '43:02',
#    'name': 'Breaking Modern Loneliness: mxmtoon [Episode 1]',
#    'views': '73K views',
#    'time': '1 year ago'},
#   {'duration': '28:56',
#    'name': 'Breaking Modern Loneliness: Jeremy Zucker [Episode 3]',
#    'views': '96K views',
#    'time': '1 year ago'},
#   {'duration': '34:41',
#    'name': 'Breaking Modern Loneliness: Dr. Vivek Murthy [Episode 2]',
#    'views': '19K views',
#    'time': '1 year ago'},
#   {'duration': '4:09',
#    'name': 'Lauv - El Tejano (feat. Sofía Reyes) [Official Video]',
#    'views': '4.6M views',
#    'time': '1 year ago'},
#   {'duration': '3:05',
#    'name': 'Lauv - Love Like That [Official Audio]',
#    'views': '2.6M views',
#    'time': '1 year ago'},
#   {'duration': '58:39',
#    'name': 'Breaking Modern Loneliness: A Conversation on Mental Health',
#    'views': '266K views',
#    'time': 'Streamed 1 year ago'},
#   {'duration': '4:07',
#    'name': 'Lauv - Modern Loneliness (MTV Live Performance)',
#    'views': '521K views',
#    'time': '1 year ago'}],
#  'comments_count': '170',
#  'comments': [{'name': 'aestaetic ʕ•ᴥ•ʔ',
#    'time': '7 months ago',
#    'comments': 'Lauv and Alec! What a powerful duo this would be! :D',
#    'likes': '162'},
#   {'name': 'TwoFeet',
#    'time': '7 months ago',
#    'comments': 'Thanks for having me <3 sorry for not saying much in the beginning it can be hard to talk about. Love you guys.',
#    'likes': '260'},
#   {'name': 'LyricsThisWeekend',
#    'time': '7 months ago',
#    'comments': 'Alec and Lauv, we love you guys both!!! ',
#    'likes': 'My special message is to Alec tho,'},
#   {'name': 'arimar',
#    'time': '7 months ago',
#    'comments': 'I love the music of Alec benjamín and that of Lauv Haci this will be an extraordinary bomb of beautiful voices💥💥💥💜💜💙💙💯',
#    'likes': '95'},
#   {'name': 'Mars Loli',
#    'time': '7 months ago',
#    'comments': 'Thanks for this Lauv, I definitely needed this, seeing celebrities talking about their issues and comments on mental health is amazing <3',
#    'likes': '5'},
#   {'name': 'Nayana',
#    'time': '7 months ago',
#    'comments': 'Holy fuck what I didn’t expect this duo but I honestly love it they are both my fav artists ❤️',
#    'likes': '39'},
#   {'name': 'Josh Yuknowwho',
#    'time': '7 months ago',
#    'comments': 'Alec is the best person to share your thoughts with',
#    'likes': '8'},
#   {'name': 'Nicol3',
#    'time': '7 months ago',
#    'comments': 'Hope to break this Modern Loneliness within soon 🤞So much love for Lauv ❤️',
#    'likes': '5'},
#   {'name': 'Lob zan',
#    'time': '7 months ago (edited)',
#    'comments': 'Okay so i just finished this whole conversation i mean such a good inititaive by Lauv and blue foundation .I found everyone in the video so sweet but Two Feet stood out for me as those who watched from the very beginning to the end would know at first he seem lil uncomfortable sharing but as he listens to others sharing their experiences he also shared his darkest moments in life and at the end of the conversation he seems so comfortable and happy to share those with them and to all the people out there and the way he said he love his dog i mean wow...i just loved how he became comfortable at the end',
#    'likes': 'Read more'},
#   {'name': 'Ayushi Maldeniya',
#    'time': '7 months ago',
#    'comments': 'I love this song so much! It helps me a lot during bad times 🤍',
#    'likes': '17'},
#   {'name': 'Sneakermikaa',
#    'time': '7 months ago',
#    'comments': 'I kind of liked the way that they made me think about all of these questions and try to answer them myself..It was like I had a chat with all of them myself...that was awesome.',
#    'likes': 'Huge thank you♡'},
#   {'name': 'Jieun Jeannie Oh',
#    'time': '7 months ago',
#    'comments': 'It was really good to hear public figures share their personal experience, ',
#    'likes': 'And now i’m thinking all people are same, and we all try to overcome their mood issues which is great 💪🏻'},
#   {'name': 'Call me Wolfie',
#    'time': '7 months ago',
#    'comments': 'you guys are just amazing.',
#    'likes': '6'},
#   {'name': 'Desang',
#    'time': '7 months ago',
#    'comments': "These people are so inspiring and yet.. We all facing different struggle everyday but here's a reminder that we are not alone. 💖 Thank you so much Lauv 💞",
#    'likes': '3'},
#   {'name': 'Drake Vermillion',
#    'time': '3 months ago',
#    'comments': "I actually watched this video till the end and I learned a lot from these lovely artists. Mental health is really important especially on this era, lot of people tend to hide and ignore their feelings and ain't open up their  problems to friends and family.",
#    'likes': 'REPLY'},
#   {'name': 'Tri Febiani',
#    'time': '7 months ago',
#    'comments': 'always love ur music so bad💙',
#    'likes': '6'},
#   {'name': 'heidewia',
#    'time': '7 months ago',
#    'comments': 'conversations about  mental health on my birthday, thank you Blue Boy Foundation 🤍',
#    'likes': '8'},
#   {'name': 'Leslie Hipolito',
#    'time': '7 months ago',
#    'comments': 'Thank you for this! ❤️😥',
#    'likes': '2'}]}
